# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
simpsons=pd.read_html('https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes')

# %%
len(simpsons)
# Out:
# 16

# %%
type(simpsons)
# Out:
# list

# %%
simpsons[2]
# Out:
#                                                Title      Directed by  \
# 0                     The Force Awakens from Its Nap  David Silverman
# 1                   The Good, the Bart, and the Loki  David Silverman
# 2                                       Plusaversary  David Silverman
# 3                               When Billie Met Lisa  David Silverman
# 4                                Welcome to the Club  David Silverman
# 5  The Simpsons Meet the Bocellis in 'Feliz Navidad'  David Silverman
# 6                                Rogue Not Quite One  David Silverman
# 7                           May the 12th Be with You  David Silverman
# 8                The Most Wonderful Time of the Year  David Silverman
#
#                                           Written by Original release date
# 0             Joel H. Cohen, Al Jean & Michael Price           May 4, 2021
# 1  Elisabeth Kiernan Averick, Jessica Conrad, Joh...          July 7, 2021
# ...

# %%
football_dt=pd.read_csv('https://www.football-data.co.uk/mmz4281/2324/E3.csv')

# %%
type(football_dt)
# Out:
# pandas.core.frame.DataFrame

# %%
football_dt
# Out:
#     Div        Date   Time            HomeTeam        AwayTeam  FTHG  FTAG  \
# 0    E3  05/08/2023  15:00          Accrington  Newport County     3     0
# 1    E3  05/08/2023  15:00        Crawley Town        Bradford     1     0
# 2    E3  05/08/2023  15:00               Crewe       Mansfield     2     2
# 3    E3  05/08/2023  15:00           Doncaster       Harrogate     0     1
# 4    E3  05/08/2023  15:00        Forest Green         Salford     0     2
# ..   ..         ...    ...                 ...             ...   ...   ...
# 547  E3  27/04/2024  15:00          Gillingham       Doncaster     2     2
# 548  E3  27/04/2024  15:00  Milton Keynes Dons          Sutton     4     4
# 549  E3  27/04/2024  15:00             Salford       Harrogate     2     2
# 550  E3  27/04/2024  15:00             Swindon       Morecambe     3     3
# 551  E3  27/04/2024  15:00             Wrexham       Stockport     2     1
#
# ...

# %%
football_dt.rename(columns={'B365CAHH':'demo1','B365CAHA':'demo2'},inplace=True)

# %%
football_dt
# Out:
#     Div        Date   Time            HomeTeam        AwayTeam  FTHG  FTAG  \
# 0    E3  05/08/2023  15:00          Accrington  Newport County     3     0
# 1    E3  05/08/2023  15:00        Crawley Town        Bradford     1     0
# 2    E3  05/08/2023  15:00               Crewe       Mansfield     2     2
# 3    E3  05/08/2023  15:00           Doncaster       Harrogate     0     1
# 4    E3  05/08/2023  15:00        Forest Green         Salford     0     2
# ..   ..         ...    ...                 ...             ...   ...   ...
# 547  E3  27/04/2024  15:00          Gillingham       Doncaster     2     2
# 548  E3  27/04/2024  15:00  Milton Keynes Dons          Sutton     4     4
# 549  E3  27/04/2024  15:00             Salford       Harrogate     2     2
# 550  E3  27/04/2024  15:00             Swindon       Morecambe     3     3
# 551  E3  27/04/2024  15:00             Wrexham       Stockport     2     1
#
# ...
